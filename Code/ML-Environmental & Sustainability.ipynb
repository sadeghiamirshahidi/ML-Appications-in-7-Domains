# %%
# Import Required Packages
import matplotlib.pyplot as plt
import numpy as np

# %%
# Data
ml_method_types = ["Supervised", "Unsupervised", "Reinforcement", "Deep Learning"]
numbers = np.array([94, 10, 13, 54])

# %%
# Sort data in descending order for Pareto
sorted_indices = np.argsort(numbers)[::-1]
ml_method_types_sorted = np.array(ml_method_types)[sorted_indices]
numbers_sorted = numbers[sorted_indices]

# Calculate cumulative percentage
cumulative = np.cumsum(numbers_sorted)
cumulative_percent = 100 * cumulative / cumulative[-1]

# %% [markdown]
# ### Pareto Chart for ML Methods in Environmental & Sustainability

# %%
# Create figure and twin axis
fig, ax1 = plt.subplots(figsize=(8, 6))

# Bar chart (frequency)
ax1.bar(ml_method_types_sorted, numbers_sorted, color='darkblue', edgecolor='black')
ax1.set_ylabel("Number of Papers", fontsize=12)
ax1.tick_params(axis='x', rotation=15)

# Adjust title position to avoid overlap
plt.title("ML Method in Environmental & Sustainability", fontsize=14, fontweight='bold', pad=30)

# Line chart (cumulative percentage)
ax2 = ax1.twinx()
ax2.plot(ml_method_types_sorted, cumulative_percent, color='red', marker='o', linewidth=2)
ax2.set_ylabel("Cumulative Percentage (%)", fontsize=12)
ax2.yaxis.set_ticks(np.arange(0, 110, 10))

# Add cumulative percentage labels (shifted slightly lower)
for i, val in enumerate(cumulative_percent):
    ax2.text(i, val - 5, f"{val:.1f}%", ha='center', color='red', fontsize=9)

# Add grid and layout adjustment
ax1.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout(rect=[0, 0, 1, 0.95])  # Adds extra space on top
plt.show()

# %% [markdown]
# ### Pareto Chart for Supervised ML Methods in Environmental & Sustainability

# %%
# Data (corrected "atural" -> "Natural")
algorithms = [
    "Decision Tree (DT)",
    "K Nearest Neighbors (K-NN)",
    "LASSO Regression",
    "Logistic Regression (LR)",
    "Naive Bayes Classifier (NBC)",
    "Random Forest (RF)",
    "Support Vector Machine (SVM)",
    "Linear Regression"
]
counts = np.array([4, 6, 3, 4, 2, 46, 25, 9])

# %%
# Sort in descending order for Pareto chart
order = np.argsort(counts)[::-1]
alg_sorted = np.array(algorithms)[order]
counts_sorted = counts[order]

# Calculate cumulative percentage
cum = np.cumsum(counts_sorted)
cum_pct = 100 * cum / cum[-1]

# %%
# Create Pareto chart
fig, ax1 = plt.subplots(figsize=(10, 6))

# Bar chart (frequencies)
bars = ax1.bar(range(len(alg_sorted)), counts_sorted, color='darkblue', edgecolor='black')
ax1.set_ylabel("Number of Papers", fontsize=12)

# Place algorithm names below the x-axis, centered to each bar
ax1.set_xticks(range(len(alg_sorted)))
ax1.set_xticklabels(alg_sorted, rotation=25, ha='right', fontsize=9)

# Title with spacing
plt.title("Supervised ML Algorithms in Environmental & Sustainability", fontsize=14, fontweight='bold', pad=30)

# Cumulative percentage line (right axis)
ax2 = ax1.twinx()
ax2.plot(range(len(alg_sorted)), cum_pct, color='red', marker='o', linewidth=2)
ax2.set_ylabel("Cumulative Percentage (%)", fontsize=12)
ax2.set_ylim(0, 105)
ax2.yaxis.set_ticks(np.arange(0, 110, 10))

# Annotate cumulative % labels BELOW each point
for i, v in enumerate(cum_pct):
    ax2.text(i, v - 7, f"{v:.1f}%", ha='center', va='top', fontsize=9, color='red')

# Grid + layout adjustment
ax1.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout(rect=[0, 0, 1, 0.93])
plt.show()

# %% [markdown]
# ### Pareto Chart for Unsupervised ML Methods in Environmental & Sustainability

# %%
# Data (corrected "atural" -> "Natural")
algorithms = [
    "Gaussian Mixture Model (GMM)",
    "Hierarchical Clustering (HC)",
    "K-Means Clustering (KMC)",
    "Self-Organizing Map (SOM)",
    "Support Vector Regression (SVR)",
]
counts = np.array([1, 1, 2, 1, 1])

# %%
# Sort in descending order for Pareto chart
order = np.argsort(counts)[::-1]
alg_sorted = np.array(algorithms)[order]
counts_sorted = counts[order]

# Calculate cumulative percentage
cum = np.cumsum(counts_sorted)
cum_pct = 100 * cum / cum[-1]

# %%
# Create Pareto chart
fig, ax1 = plt.subplots(figsize=(10, 6))

# Bar chart (frequencies)
bars = ax1.bar(range(len(alg_sorted)), counts_sorted, color='darkblue', edgecolor='black')
ax1.set_ylabel("Number of Papers", fontsize=12)

# Place algorithm names below the x-axis, centered to each bar
ax1.set_xticks(range(len(alg_sorted)))
ax1.set_xticklabels(alg_sorted, rotation=25, ha='right', fontsize=9)

# Title with spacing
plt.title("Unsupervised ML Algorithms in Environmental & Sustainability", fontsize=14, fontweight='bold', pad=30)

# Cumulative percentage line (right axis)
ax2 = ax1.twinx()
ax2.plot(range(len(alg_sorted)), cum_pct, color='red', marker='o', linewidth=2)
ax2.set_ylabel("Cumulative Percentage (%)", fontsize=12)
ax2.set_ylim(0, 105)
ax2.yaxis.set_ticks(np.arange(0, 110, 10))

# Annotate cumulative % labels BELOW each point
for i, v in enumerate(cum_pct):
    ax2.text(i, v - 7, f"{v:.1f}%", ha='center', va='top', fontsize=9, color='red')

# Grid + layout adjustment
ax1.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout(rect=[0, 0, 1, 0.93])
plt.show()

# %% [markdown]
# ### Pareto Chart for Deep Learning ML Methods in Environmental & Sustainability

# %%
# Data (corrected "atural" -> "Natural")
algorithms = [
    "Artificial Neural Network (ANN)",
    "Convolutional Neural Networks (CNNs)",
    "Recurrent Neural Networks (RNNs)",
]
counts = np.array([3, 6, 1])

# %%
# Sort in descending order for Pareto chart
order = np.argsort(counts)[::-1]
alg_sorted = np.array(algorithms)[order]
counts_sorted = counts[order]

# Calculate cumulative percentage
cum = np.cumsum(counts_sorted)
cum_pct = 100 * cum / cum[-1]

# %%
# Create Pareto chart
fig, ax1 = plt.subplots(figsize=(10, 6))

# Bar chart (frequencies)
bars = ax1.bar(range(len(alg_sorted)), counts_sorted, color='darkblue', edgecolor='black')
ax1.set_ylabel("Number of Papers", fontsize=12)

# Place algorithm names below the x-axis, centered to each bar
ax1.set_xticks(range(len(alg_sorted)))
ax1.set_xticklabels(alg_sorted, rotation=25, ha='right', fontsize=9)

# Title with spacing
plt.title("Deep Learning ML Algorithms in Environmental & Sustainability", fontsize=14, fontweight='bold', pad=30)

# Cumulative percentage line (right axis)
ax2 = ax1.twinx()
ax2.plot(range(len(alg_sorted)), cum_pct, color='red', marker='o', linewidth=2)
ax2.set_ylabel("Cumulative Percentage (%)", fontsize=12)
ax2.set_ylim(0, 105)
ax2.yaxis.set_ticks(np.arange(0, 110, 10))

# Annotate cumulative % labels BELOW each point
for i, v in enumerate(cum_pct):
    ax2.text(i, v - 7, f"{v:.1f}%", ha='center', va='top', fontsize=9, color='red')

# Grid + layout adjustment
ax1.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout(rect=[0, 0, 1, 0.93])
plt.show()

# %% [markdown]
# ### Pareto Chart for Reinforcement Learning  ML Methods in Environmental & Sustainability

# %%
# Data (corrected "atural" -> "Natural")
algorithms = [
    "Deep Q-Learning",
    "Q-Learning",
]
counts = np.array([1, 12])

# %%
# Sort in descending order for Pareto chart
order = np.argsort(counts)[::-1]
alg_sorted = np.array(algorithms)[order]
counts_sorted = counts[order]

# Calculate cumulative percentage
cum = np.cumsum(counts_sorted)
cum_pct = 100 * cum / cum[-1]

# %%
# Create Pareto chart
fig, ax1 = plt.subplots(figsize=(10, 6))

# Bar chart (frequencies)
bars = ax1.bar(range(len(alg_sorted)), counts_sorted, color='darkblue', edgecolor='black')
ax1.set_ylabel("Number of Papers", fontsize=12)

# Place algorithm names below the x-axis, centered to each bar
ax1.set_xticks(range(len(alg_sorted)))
ax1.set_xticklabels(alg_sorted, rotation=25, ha='right', fontsize=9)

# Title with spacing
plt.title("Reinforcement Learning ML Algorithms in Environmental & Sustainability", fontsize=14, fontweight='bold', pad=30)

# Cumulative percentage line (right axis)
ax2 = ax1.twinx()
ax2.plot(range(len(alg_sorted)), cum_pct, color='red', marker='o', linewidth=2)
ax2.set_ylabel("Cumulative Percentage (%)", fontsize=12)
ax2.set_ylim(0, 105)
ax2.yaxis.set_ticks(np.arange(0, 110, 10))

# Annotate cumulative % labels BELOW each point
for i, v in enumerate(cum_pct):
    ax2.text(i, v - 7, f"{v:.1f}%", ha='center', va='top', fontsize=9, color='red')

# Grid + layout adjustment
ax1.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout(rect=[0, 0, 1, 0.93])
plt.show()
