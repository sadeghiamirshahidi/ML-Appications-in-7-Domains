# %%
import pandas as pd
import matplotlib.pyplot as plt

# Data
data = {
    'Supervised': {
        'DT': 3,
        'LAR': 3,
        'LR': 1,
        'NBC': 2,
        'RF': 12,
        'SVM': 14,
        'BRT': 8,
        'Lin-R': 2
    },
    'Unsupervised': {
        'GMM': 1,
        'KMC': 1
    },
    'Deep Learning': {
        'ANN': 7,
        'CNNs': 7,
        'RNNs': 2,
        'DNNs': 15
    }
}

# Convert to DataFrame
df = pd.DataFrame(data).fillna(0)

# Colors (same as previous)
colors = {
    'Supervised': '#1f77b4',            # blue
    'Unsupervised': '#ff7f0e',          # orange
    'Deep Learning': '#2ca02c',         # green
    'Reinforcement Learning': '#d62728' # red
}

# Convert to DataFrame (rows = algorithms, columns = method types)
df = pd.DataFrame(data).fillna(0)

# Matplotlib default colors (matching your figure)
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']

# Plot stacked bar chart
ax = df.T.plot(
    kind='bar',
    stacked=True,
    figsize=(10, 6),
    colormap=None
)

# Manually apply colors to stacks
for i, bar in enumerate(ax.containers):
    for patch in bar:
        patch.set_facecolor(colors[i % len(colors)])

# Labels and formatting
plt.title('Stacked Bar Chart of ML Algorithms by Method Type', fontsize=14)
plt.xlabel('ML Method Type')
plt.ylabel('Number of Studies')
plt.xticks(rotation=0)
plt.legend(title='Algorithms', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()
